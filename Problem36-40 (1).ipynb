# %% [markdown]
# # Python Pratice Notebook 36-40

# %% [markdown]
# 11 Oct 2020

# %% [markdown]
# Problem 36

# %%
file = open(input())
for line in reversed(file.readlines()):
    print(line.strip())
# Out:
#  Untitled.txt
# }
# "nbformat_minor": 4
# "nbformat": 4,
# },
# }
# "version": "3.7.8"
# "pygments_lexer": "ipython3",
# "nbconvert_exporter": "python",
# "name": "python",
# "mimetype": "text/x-python",
# "file_extension": ".py",
# },
# "version": 3
# "name": "ipython",
# "codemirror_mode": {
# "language_info": {
# },
# "name": "python3"
# "language": "python",
# "display_name": "Python 3",
# "kernelspec": {
# "metadata": {
# ],
# }
# ]
# "I love Programming"
# "source": [
# ],
# }
# ]
# "\u001b  File \u001b\"<ipython-input-1-e5f1740f579e>\"\u001b, line \u001b1\u001b\n\u001b    I love Programming\u001b\n\u001b         ^\u001b\n\u001bSyntaxError\u001b\u001b:\u001b invalid syntax\n"
# "traceback": [
# "output_type": "error",
# "evalue": "invalid syntax (<ipython-input-1-e5f1740f579e>, line 1)",
# "ename": "SyntaxError",
# {
# "outputs": [
# "metadata": {},
# "execution_count": 1,
# "cell_type": "code",
# {
# "cells": [
# {

# %% [markdown]
# Problem 37

# %%
file = open(input())
for line in reversed(file.readlines()):
    print(line.strip())
# Out:
#  Untitled.txt
# }
# "nbformat_minor": 4
# "nbformat": 4,
# },
# }
# "version": "3.7.8"
# "pygments_lexer": "ipython3",
# "nbconvert_exporter": "python",
# "name": "python",
# "mimetype": "text/x-python",
# "file_extension": ".py",
# },
# "version": 3
# "name": "ipython",
# "codemirror_mode": {
# "language_info": {
# },
# "name": "python3"
# "language": "python",
# "display_name": "Python 3",
# "kernelspec": {
# "metadata": {
# ],
# }
# ]
# "I love Programming"
# "source": [
# ],
# }
# ]
# "\u001b  File \u001b\"<ipython-input-1-e5f1740f579e>\"\u001b, line \u001b1\u001b\n\u001b    I love Programming\u001b\n\u001b         ^\u001b\n\u001bSyntaxError\u001b\u001b:\u001b invalid syntax\n"
# "traceback": [
# "output_type": "error",
# "evalue": "invalid syntax (<ipython-input-1-e5f1740f579e>, line 1)",
# "ename": "SyntaxError",
# {
# "outputs": [
# "metadata": {},
# "execution_count": 1,
# "cell_type": "code",
# {
# "cells": [
# {

# %% [markdown]
# Problem 38

# %%
file = open(input())
for line in reversed(file.readlines()):
    print(line.strip())
# Out:
#  Untitled.txt
# }
# "nbformat_minor": 4
# "nbformat": 4,
# },
# }
# "version": "3.7.8"
# "pygments_lexer": "ipython3",
# "nbconvert_exporter": "python",
# "name": "python",
# "mimetype": "text/x-python",
# "file_extension": ".py",
# },
# "version": 3
# "name": "ipython",
# "codemirror_mode": {
# "language_info": {
# },
# "name": "python3"
# "language": "python",
# "display_name": "Python 3",
# "kernelspec": {
# "metadata": {
# ],
# }
# ]
# "I love Programming"
# "source": [
# ],
# }
# ]
# "\u001b  File \u001b\"<ipython-input-1-e5f1740f579e>\"\u001b, line \u001b1\u001b\n\u001b    I love Programming\u001b\n\u001b         ^\u001b\n\u001bSyntaxError\u001b\u001b:\u001b invalid syntax\n"
# "traceback": [
# "output_type": "error",
# "evalue": "invalid syntax (<ipython-input-1-e5f1740f579e>, line 1)",
# "ename": "SyntaxError",
# {
# "outputs": [
# "metadata": {},
# "execution_count": 1,
# "cell_type": "code",
# {
# "cells": [
# {

# %% [markdown]
# Problem 39

# %%
file,text = [i for i in input().split()]
for line in open(file):
    if (text in line):
        print(line.strip())
# Out:
#  Untitled.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c9158570a0c9> in <module>
# ----> 1 file,text = [i for i in input().split()]
#       2 for line in open(file):
#       3     if (text in line):
#       4         print(line.strip())
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# Problem 40

# %%
import textwrap
file, size = [i for i in input().split()]
for line in open(file):
    [print(line[i:i + size]) for i in range(0, len(arr), size)
# Out:
#   File "<ipython-input-6-2457138e6dda>", line 4
#     [print(line[i:i + size]) for i in range(0, len(arr), size)
#                                                               ^
# SyntaxError: unexpected EOF while parsing
